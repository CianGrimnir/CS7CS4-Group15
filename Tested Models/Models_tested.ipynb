# %% [markdown]
# ###Model for whole dataset

# %% [markdown]
# Ridge with hyper parameter tuning

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split
from matplotlib.pyplot import figure
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split



feature = pd.read_csv('sample_data/normalized cleaned children in poverty (UNDER 18) 2006-2016.csv')
target = pd.read_csv('sample_data/normalized cleaned crime rates 2000-2017.csv')

feature_cols =feature.columns
for i in range(len(feature.columns)):
  # print(f" score {feature[].corr(target['2006.0'])}")
  print(f" Correlation {feature[feature_cols[i]].corr(target[feature_cols[i]])}")
# print(type(feature_matrix[0][0]))
feature_matrix = feature.iloc[:,:].to_numpy()
# print(target.iloc[:,6:17])
target_matrix = target.iloc[:,6:17].to_numpy()

# corr = np.corrcoef(feature_matrix,target_matrix)
# print(len(corr[0]))
Xtrain, Xtest, ytrain, ytest = train_test_split(feature_matrix,target_matrix,test_size=0.2)
# Xtrain= Xtrain.reshape(-1, 1)
# ytrain= ytrain.reshape(-1, 1)
C=[5,10,50,100,1000,1500,2000,3000,4000,10000]
from sklearn.linear_model import Ridge
from sklearn.linear_model import LogisticRegression
for Ci in C:
  model = Ridge(alpha=1/(2*Ci),max_iter=7000)
  
  model.fit(Xtrain,ytrain)
  # print(f" coefficient value for c= {Ci} are: \n {model.coef_} and \n intercept = {model.intercept_}")
  print(model.score(Xtest,ytest))
  from sklearn.metrics import r2_score
  ypred = model.predict(Xtest)
# Out:
#  Correlation 0.6581946526974778
#  Correlation 0.652354479447452
#  Correlation 0.6600398102980913
#  Correlation 0.60757124759862
#  Correlation 0.612021347288126
#  Correlation 0.6142325446745529
#  Correlation 0.5758156102976213
#  Correlation 0.629044968781324
#  Correlation 0.6535636025679943
#  Correlation 0.7397255118805357
#  Correlation 0.750621003243022
# 0.834027333912838
#  r2 for same 0.834027333912838
# 0.7527445056887458
#  r2 for same 0.7527445056887458
# 0.39597296961950906
#  r2 for same 0.39597296961950906
# 0.21705074623203596
#  r2 for same 0.21705074623203596
# -0.22721794778875484
#  r2 for same -0.22721794778875484
# -0.2476651369811931
#  r2 for same -0.2476651369811931
# -0.2499668829678961
#  r2 for same -0.2499668829678961
# -0.2405213865060108
#  r2 for same -0.2405213865060108
# -0.2282903882075195
#  r2 for same -0.2282903882075195
# -0.18402995179546727
#  r2 for same -0.18402995179546727

# %% [markdown]
# Lasso with hyper Parameter

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split
from matplotlib.pyplot import figure
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split



feature = pd.read_csv('sample_data/normalized cleaned children in poverty (UNDER 18) 2006-2016.csv')
target = pd.read_csv('sample_data/normalized cleaned crime rates 2000-2017.csv')

feature_cols =feature.columns
for i in range(len(feature.columns)):
  # print(f" score {feature[].corr(target['2006.0'])}")
  print(f" Correlation {feature[feature_cols[i]].corr(target[feature_cols[i]])}")
print(type(feature_matrix[0][0]))
feature_matrix = feature.iloc[:,:].to_numpy()
# print(target.iloc[:,6:17])
target_matrix = target.iloc[:,6:17].to_numpy()

# corr = np.corrcoef(feature_matrix,target_matrix)
# print(len(corr[0]))
Xtrain, Xtest, ytrain, ytest = train_test_split(feature_matrix,target_matrix,test_size=0.2)
# Xtrain= Xtrain.reshape(-1, 1)
# ytrain= ytrain.reshape(-1, 1)
C=[5,10,50,100,1000,1500,2000,3000,4000,10000]
from sklearn.linear_model import Ridge
from sklearn.linear_model import LogisticRegression
for Ci in C:
  model = Lasso(alpha=1/(2*Ci),max_iter=7000)
  
  model.fit(Xtrain,ytrain)
  # print(f" coefficient value for c= {Ci} are: \n {model.coef_} and \n intercept = {model.intercept_}")
  print(model.score(Xtrain,ytrain))
# Out:
#  Correlation 0.6581946526974778
#  Correlation 0.652354479447452
#  Correlation 0.6600398102980913
#  Correlation 0.60757124759862
#  Correlation 0.612021347288126
#  Correlation 0.6142325446745529
#  Correlation 0.5758156102976213
#  Correlation 0.629044968781324
#  Correlation 0.6535636025679943
#  Correlation 0.7397255118805357
#  Correlation 0.750621003243022
# <class 'numpy.float64'>
# 1.0092936587501423e-17
# 1.0092936587501423e-17
# 0.007303129928928756
# 0.17221605054870032
# 0.521608257938635
# 0.5546188198624956
# 0.5928782173913473
# 0.6322475512791363
# 0.6637509841588298
# 0.7898451222789137

# %% [markdown]
# Normal lasso

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split
from matplotlib.pyplot import figure
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split



feature = pd.read_csv('sample_data/normalized cleaned children in poverty (UNDER 18) 2006-2016.csv')
target = pd.read_csv('sample_data/normalized cleaned crime rates 2000-2017.csv')

feature_cols =feature.columns
for i in range(len(feature.columns)):
  # print(f" score {feature[].corr(target['2006.0'])}")
  print(f" Correlation {feature[feature_cols[i]].corr(target[feature_cols[i]])}")

feature_matrix = feature.iloc[:,:].to_numpy()
# print(target.iloc[:,6:17])
target_matrix = target.iloc[:,6:17].to_numpy()

corr = np.corrcoef(feature_matrix,target_matrix)
print(len(corr[0]))
Xtrain, Xtest, ytrain, ytest = train_test_split(feature_matrix,target_matrix,test_size=0.2)
# Xtrain= Xtrain.reshape(-1, 1)
# ytrain= ytrain.reshape(-1, 1)
C=[5,10,50,100,1000,1500,2000,3000,4000,10000]

model = Lasso(alpha=1/(2*1000),max_iter=7000)
model.fit(Xtrain,ytrain)
# print(f" coefficient value for c= {Ci} are: \n {model.coef_} and \n intercept = {model.intercept_}")
print(model.score(Xtrain,ytrain))
# Out:
#  Correlation 0.6581946526974778
#  Correlation 0.652354479447452
#  Correlation 0.6600398102980913
#  Correlation 0.60757124759862
#  Correlation 0.612021347288126
#  Correlation 0.6142325446745529
#  Correlation 0.5758156102976213
#  Correlation 0.629044968781324
#  Correlation 0.6535636025679943
#  Correlation 0.7397255118805357
#  Correlation 0.750621003243022
# 64
# 0.523321069570436

# %% [markdown]
# With kfold

# %%
mean_error=[]
std_error=[]
C=[100,500,1000,1500,2000,3000,4000]
for Ci in C:
  model = Lasso(alpha=1/(2*Ci),max_iter=10000)
  temp=[]
  from sklearn.model_selection import KFold
  kf = KFold(n_splits=5)
  for train,test in kf.split(feature_matrix):
    model.fit(feature_matrix[train],target_matrix[train])
    print(f"for c= {Ci} {model.score(feature_matrix[test],target_matrix[test])}")
    ypred = model.predict(feature_matrix[test])
    from sklearn.metrics import mean_squared_error
    temp.append(mean_squared_error(target_matrix[test],ypred))
  mean_error.append(np.array(temp).mean())
  std_error.append(np.array(temp).std())
print(f"mean error:{mean_error}")
print(f"std error:{std_error}")

plt.errorbar(C,mean_error,yerr=std_error)
plt.xlabel('C'); plt.ylabel('Mean square error')
plt.title("Lasso Regression")
plt.show()
# Out:
# for c= 100 0.30745093276854285
# for c= 100 0.09623709555877837
# for c= 100 0.44673401521869477
# for c= 100 0.4086185143406652
# for c= 100 -0.10711623693607247
# for c= 500 0.7212801974175783
# for c= 500 0.17980554224825182
# for c= 500 0.7651094651510032
# for c= 500 0.7841821994293533
# for c= 500 0.04868860738470611
# for c= 1000 0.7270725541147528
# for c= 1000 0.17031035409385498
# for c= 1000 0.7235541648313016
# for c= 1000 0.5955638898261794
# for c= 1000 0.15014103792382583
# for c= 1500 0.6889985850359281
# for c= 1500 0.19127136017800891
# for c= 1500 0.6739604829749506
# for c= 1500 0.37580151192759387
# for c= 1500 0.18754486328569478
# for c= 2000 0.7093407604760927
# for c= 2000 0.24388748184565168
# for c= 2000 0.6755953567770011
# for c= 2000 0.3220538063015059
# for c= 2000 0.2071808974659165
# for c= 3000 0.7395799065414064
# for c= 3000 0.39058053892963485
# for c= 3000 0.6645105385122898
# for c= 3000 0.2984961440317471
# for c= 3000 0.22748148287369016
# ...

# %% [markdown]
# ## Model for column with highest correlation

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split
from matplotlib.pyplot import figure
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split



feature = pd.read_csv('sample_data/normalized cleaned children in poverty (UNDER 18) 2006-2016.csv')
target = pd.read_csv('sample_data/normalized cleaned crime rates 2000-2017.csv')

feature_cols =feature.columns
for i in range(len(feature.columns)):
  # print(f" score {feature[].corr(target['2006.0'])}")
  print(f" Correlation {feature[feature_cols[i]].corr(target[feature_cols[i]])}")

feature_matrix = feature.iloc[:,10].to_numpy()
# print(target.iloc[:,6:17])
target_matrix = target.iloc[:,17].to_numpy()

corr = np.corrcoef(feature_matrix,target_matrix)
print(len(corr[0]))
Xtrain, Xtest, ytrain, ytest = train_test_split(feature_matrix,target_matrix,test_size=0.2)
Xtrain= Xtrain.reshape(-1, 1)
ytrain= ytrain.reshape(-1, 1)
Xtest= Xtest.reshape(-1, 1)
ytest= ytest.reshape(-1, 1)
C=[5,10,50,100,1000,1500,2000,3000,4000,10000]
for Ci in C:
  model = Ridge(alpha=1/(2*Ci),max_iter=10000)
  model.fit(Xtrain,ytrain)
  # print(f" coefficient value for c= {Ci} are: \n {model.coef_} and \n intercept = {model.intercept_}")
  print(model.score(Xtest,ytest))
# Out:
#  Correlation 0.6581946526974778
#  Correlation 0.652354479447452
#  Correlation 0.6600398102980913
#  Correlation 0.60757124759862
#  Correlation 0.612021347288126
#  Correlation 0.6142325446745529
#  Correlation 0.5758156102976213
#  Correlation 0.629044968781324
#  Correlation 0.6535636025679943
#  Correlation 0.7397255118805357
#  Correlation 0.750621003243022
# 2
# 0.4739304138676347
# 0.46822748966416017
# 0.4237776566287744
# 0.4137156816095119
# 0.4034738467231139
# 0.40307140134210795
# 0.40286953793400404
# 0.4026672463460328
# 0.4025659397415089
# 0.40238331729892785

# %%
# from sklearn.linear_model import Ridge
# C=[0.001,0.01,0.1,1,5,10,50,100,500,1000,1500]
# mean_error=[]
# std_error=[]
# for Ci in C:
#   model = Ridge(alpha=1/(2*Ci))
#   temp=[]
#   from sklearn.model_selection import KFold
#   kf = KFold(n_splits=5)
#   for train,test in kf.split(feature_matrix):
#     model.fit(feature_matrix[train],target_matrix[train])
#     ypred = model.predict(feature_matrix[test])
#     from sklearn.metrics import mean_squared_error
#     temp.append(mean_squared_error(target_matrix[test],ypred))
#     print(model.score(feature_matrix[test],target_matrix[test]))
#   mean_error.append(np.array(temp).mean())
#   std_error.append(np.array(temp).std())

# print(mean_error)
# print(std_error)
# plt.errorbar(C,mean_error,yerr=std_error)
# plt.xlabel('C'); plt.ylabel('Mean square error')
# plt.title("Ridge Regression")
# plt.show()
# Out:
# -0.14275029439357054
# -0.052599510544808825
# 0.001258637734453954
# -0.30886867948943963
# -0.21723078112621572
# -0.03565538767738819
# 0.007167093639300116
# 0.11598340018477972
# -0.1123794850744284
# -0.18176475887482976
# 0.40206595732019623
# 0.1375193246838994
# 0.5480799597176612
# 0.6004600007689033
# -0.014790219434787704
# 0.6629128400959153
# 0.0479962763049713
# 0.7109906749952511
# 0.8002024630689285
# 0.12037892514982049
# 0.6764557507032349
# 0.09645818575579602
# 0.7121046818560041
# 0.7325591890524715
# 0.1641417049837715
# 0.6659099807562442
# 0.11706379689886239
# 0.6925449673836812
# 0.6331641059785312
# 0.18444818793103196
# 0.6881624692201725
# 0.1394184451483883
# 0.6057253240429211
# 0.4310379060511478
# 0.22840445138048973
# 0.7156036190259966
# 0.14089289459523513
# 0.558252468924925
# 0.4173916802858617
# 0.24625835694765794
# 0.7373428235554612
# 0.07405919713948962
# 0.4471557448064864
# 0.4164646702680621
# 0.29286901685930294
# 0.705460616110779
# ...

# %% [markdown]
# With cross_val

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split
from matplotlib.pyplot import figure
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split



feature = pd.read_csv('sample_data/normalized cleaned children in poverty (UNDER 18) 2006-2016.csv')
target = pd.read_csv('sample_data/normalized cleaned crime rates 2000-2017.csv')

feature_cols =feature.columns
for i in range(len(feature.columns)):
  # print(f" score {feature[].corr(target['2006.0'])}")
  print(f" Correlation {feature[feature_cols[i]].corr(target[feature_cols[i]])}")

feature_matrix = feature.iloc[:,:].to_numpy()
# print(target.iloc[:,6:17])
target_matrix = target.iloc[:,6:17].to_numpy()

corr = np.corrcoef(feature_matrix,target_matrix)
print(len(corr[0]))
Xtrain, Xtest, ytrain, ytest = train_test_split(feature_matrix,target_matrix,test_size=0.2)
Xtrain= Xtrain.reshape(-1, 1)
ytrain= ytrain.reshape(-1, 1)
C=[5,10,50,100,1000,1500,2000,3000,4000,10000]
from sklearn.linear_model import LogisticRegression
for Ci in C:
  model = LogisticRegression(max_iter=7000)
  # model.fit(Xtrain,ytrain)
  # print(f" coefficient value for c= {Ci} are: \n {model.coef_} and \n intercept = {model.intercept_}")
  from sklearn.model_selection import cross_val_score
  scores = cross_val_score(model, feature_matrix, target_matrix, cv=5, scoring='f1')
  print(scores)

# %% [markdown]
# Tried Wrapping up multi regressors

# %%
import numpy as np
from numpy import absolute

from sklearn.datasets import load_linnerud
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import LinearSVC
from sklearn.model_selection import RepeatedKFold
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import LinearSVR
from sklearn.multioutput import RegressorChain
feature = pd.read_csv('sample_data/normalized cleaned children in poverty (UNDER 18) 2006-2016.csv')
target = pd.read_csv('sample_data/normalized cleaned crime rates 2000-2017.csv')
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
feature_cols =feature.columns
for i in range(len(feature.columns)):
  # print(f" score {feature[].corr(target['2006.0'])}")
  print(f" Correlation {feature[feature_cols[i]].corr(target[feature_cols[i]])}")
# print(type(feature_matrix[0][0]))
feature_matrix = feature.iloc[:,:].to_numpy()
# print(target.iloc[:,6:17])
target_matrix = target.iloc[:,6:17].to_numpy()

# corr = np.corrcoef(feature_matrix,target_matrix)
# print(len(corr[0]))
Xtrain, Xtest, ytrain, ytest = train_test_split(feature_matrix,target_matrix,test_size=0.2)
# clf = DecisionTreeRegressor().fit(Xtrain,ytrain)
# print(clf.score(Xtest,ytest))
# feature_matrix= feature_matrix.reshape(-1, 1)
# target_matrix= target_matrix.reshape(-1, 1)

from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
# scores = cross_val_score(DecisionTreeRegressor(), Xtest, ytest, cv=5, scoring='f1')
clf = RandomForestRegressor()
svr = SVR(epsilon=0.1)
mor = MultiOutputRegressor(svr)
model = RegressorChain(clf)
# define the evaluation procedure
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate the model and collect the scores


# clf.fit(Xtrain,ytrain)
# print(clf.score(Xtest,ytest))
n_scores = cross_val_score(mor, feature_matrix, target_matrix, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
print(n_scores)
n_scores = absolute(n_scores)
# summarize performance
from numpy import mean
from numpy import std
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
#  Correlation 0.6581946526974778
#  Correlation 0.652354479447452
#  Correlation 0.6600398102980913
#  Correlation 0.60757124759862
#  Correlation 0.612021347288126
#  Correlation 0.6142325446745529
#  Correlation 0.5758156102976213
#  Correlation 0.629044968781324
#  Correlation 0.6535636025679943
#  Correlation 0.7397255118805357
#  Correlation 0.750621003243022
# [-0.07507    -0.06107559 -0.05801052 -0.05697682 -0.09937299 -0.04690647
#  -0.03737228 -0.13169077 -0.06614221 -0.04896596 -0.05734845 -0.04871812
#  -0.07262857 -0.13475294 -0.03479976 -0.07028973 -0.06223129 -0.15027623
#  -0.08327543 -0.03492292 -0.05038035 -0.12877451 -0.01803376 -0.02389767
#  -0.05829785 -0.06620722 -0.14609018 -0.05997109 -0.09599151 -0.06604535]
# MAE: 0.071 (0.035)

# %% [markdown]
# #Trying final code feature poverty dataset

# %%
import numpy as np
from numpy import absolute
import pandas as pd

from sklearn.datasets import load_linnerud
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.svm import LinearSVC
from sklearn.model_selection import RepeatedKFold
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import LinearSVR
from sklearn.multioutput import RegressorChain
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error

#parse dataset
feature = pd.read_csv('sample_data/normalized cleaned children in poverty (UNDER 18) 2006-2016.csv')
target = pd.read_csv('sample_data/normalized cleaned crime rates 2000-2017.csv')


##corelatoin among datasets
feature_cols =feature.columns
for i in range(len(feature.columns)):
  # print(f" score {feature[].corr(target['2006.0'])}")
  print(f" Correlation {feature[feature_cols[i]].corr(target[feature_cols[i]])}")
feature_matrix = feature.iloc[:,:].to_numpy()
target_matrix = target.iloc[:,17].to_numpy()


#Ridge
C=[0.001,0.01,0.1,1,5,10,50,100,500,1000,1500]
mean_error=[]
std_error=[]
for Ci in C:
  model = Ridge(alpha=1/(2*Ci))
  temp=[]
  from sklearn.model_selection import KFold
  kf = KFold(n_splits=5)
  kfld=0
  for train,test in kf.split(feature_matrix):
    model.fit(feature_matrix[train],target_matrix[train])
    ypred = model.predict(feature_matrix[test])
    from sklearn.metrics import mean_squared_error
    temp.append(mean_squared_error(target_matrix[test],ypred))
    print(f"for c= {Ci} score={model.score(feature_matrix[test],target_matrix[test])} fold{kfld}")
    kfld+=1
  mean_error.append(np.array(temp).mean())
  std_error.append(np.array(temp).std())

print(f"Mean Square error {mean_error}")
print(f"Std  error {std_error}")
plt.errorbar(C,mean_error,yerr=std_error)
plt.xlabel('C'); plt.ylabel('Mean square error')
plt.title("Ridge Regression")
plt.show()

#Lasso
C=[0.001,0.01,0.1,1,5,10,50,100,500,1000,1500]
mean_error=[]
std_error=[]
for Ci in C:
  model = Lasso(alpha=1/(2*Ci))
  temp=[]
  from sklearn.model_selection import KFold
  kf = KFold(n_splits=5)
  kfld=0
  for train,test in kf.split(feature_matrix):
    model.fit(feature_matrix[train],target_matrix[train])
    ypred = model.predict(feature_matrix[test])
    from sklearn.metrics import mean_squared_error
    temp.append(mean_squared_error(target_matrix[test],ypred))
    print(f"for c= {Ci} score={model.score(feature_matrix[test],target_matrix[test])} fold{kfld}")
    kfld+=1
  mean_error.append(np.array(temp).mean())
  std_error.append(np.array(temp).std())

print(f"Mean Square error {mean_error}")
print(f"Std  error {std_error}")
plt.errorbar(C,mean_error,yerr=std_error)
plt.xlabel('C'); plt.ylabel('Mean square error')
plt.title("Lasso Regression")
plt.show()



#RandomForest

estimators=[100, 200, 300, 1000]
mean_error=[]
std_error=[]
for Ei in estimators:
  model = RandomForestRegressor(n_estimators=Ei)
  temp=[]
  from sklearn.model_selection import KFold
  kf = KFold(n_splits=5)
  kfld=0
  for train,test in kf.split(feature_matrix):
    model.fit(feature_matrix[train],target_matrix[train])
    ypred = model.predict(feature_matrix[test])
    from sklearn.metrics import mean_squared_error
    temp.append(mean_squared_error(target_matrix[test],ypred))
    print(f"for c= {Ei} score={model.score(feature_matrix[test],target_matrix[test])} fold{kfld}")
    kfld+=1
  mean_error.append(np.array(temp).mean())
  std_error.append(np.array(temp).std())

print(f"Mean Square error {mean_error}")
print(f"Std  error {std_error}")
plt.errorbar(estimators,mean_error,yerr=std_error)
plt.xlabel('C'); plt.ylabel('Mean square error')
plt.title("Random Forest Regression")
plt.show()

#Dummy
# from sklearn.dummy import DummyRegressor
# dummy_regr = DummyRegressor(strategy="mean")
# dummy_regr.fit(X, y)


#XGBoost
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(feature_matrix,target_matrix, test_size=0.2, random_state=123)

kf = KFold(n_splits=5)
kfld=0
for train,test in kf.split(feature_matrix):
  xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,max_depth = 5, alpha = 10, n_estimators = 10)
  xg_reg.fit(feature_matrix[train],target_matrix[train])
  ypred = xg_reg.predict(feature_matrix[test])
  from sklearn.metrics import mean_squared_error
  temp.append(mean_squared_error(target_matrix[test],ypred))
  print(f"XG Boost score={model.score(feature_matrix[test],target_matrix[test])} fold{kfld}")
  kfld+=1





# preds = xg_reg.predict(X_test)

# rmse = np.sqrt(mean_squared_error(y_test, preds))
# print("RMSE: %f" % (rmse))
# Out:
#  Correlation 0.6581946526974778
#  Correlation 0.652354479447452
#  Correlation 0.6600398102980913
#  Correlation 0.60757124759862
#  Correlation 0.612021347288126
#  Correlation 0.6142325446745529
#  Correlation 0.5758156102976213
#  Correlation 0.629044968781324
#  Correlation 0.6535636025679943
#  Correlation 0.7397255118805357
#  Correlation 0.750621003243022
# for c= 0.001 score=-0.24188919766203676 fold0
# for c= 0.001 score=0.007034697173006754 fold1
# for c= 0.001 score=0.00074376604500348 fold2
# for c= 0.001 score=-0.3830760676733811 fold3
# for c= 0.001 score=-0.15305230300906625 fold4
# for c= 0.01 score=-0.12132391372343787 fold0
# for c= 0.01 score=0.07770823996703069 fold1
# for c= 0.01 score=0.07904176422129083 fold2
# for c= 0.01 score=-0.20397272667597743 fold3
# for c= 0.01 score=-0.11302588146683346 fold4
# for c= 0.1 score=0.37048262595051873 fold0
# for c= 0.1 score=0.32418910283537616 fold1
# for c= 0.1 score=0.3659952509998269 fold2
# ...

# %% [markdown]
# Trying final for Workless dataset

# %%
import numpy as np
from numpy import absolute
import pandas as pd

from sklearn.datasets import load_linnerud
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.svm import LinearSVC
from sklearn.model_selection import RepeatedKFold
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import LinearSVR
from sklearn.multioutput import RegressorChain
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error

#parse dataset
feature = pd.read_csv('sample_data/Workless_2004-2017.csv')
target = pd.read_csv('sample_data/Crime_2000-2017.csv')


##corelatoin among datasets
feature_cols =feature.columns
target_cols =target.columns
for i in range(len(feature.columns)):
  # print(f" score {feature[].corr(target['2006.0'])}")
  print(f" Correlation {feature[feature_cols[i]].corr(target[target_cols[i]])}")
  print(target.columns)
feature_matrix = feature.iloc[:,:].to_numpy()
target_matrix = target.iloc[:,3:].to_numpy()



    
X_train_test, X_val, y_train_test, y_val = sk.model_selection.train_test_split(feature_matrix, target_matrix, test_size= 0.2, random_state=42)
X_train, X_test, y_train, y_test = sk.model_selection.train_test_split(X_train_test, y_train_test, test_size= 0.25, random_state=42)
#Ridge
C=[0.001,0.01,0.1,1,5,10,50,100,500,1000,1500]
mean_error=[]
std_error=[]
for Ci in C:
  model = Ridge(alpha=1/(2*Ci))
  temp=[]
  from sklearn.model_selection import KFold
  kf = KFold(n_splits=5)
  kfld=0
  for train,test in kf.split(feature_matrix):
    model.fit(feature_matrix[train],target_matrix[train])
    ypred = model.predict(feature_matrix[test])
    from sklearn.metrics import mean_squared_error
    temp.append(mean_squared_error(target_matrix[test],ypred))
    print(f"for c= {Ci} score={model.score(feature_matrix[test],target_matrix[test])} fold{kfld}")
    kfld+=1
  mean_error.append(np.array(temp).mean())
  std_error.append(np.array(temp).std())

print(f"Mean Square error {mean_error}")
print(f"Std  error {std_error}")
plt.errorbar(C,mean_error,yerr=std_error)
plt.xlabel('C'); plt.ylabel('Mean square error')
plt.title("Ridge Regression")
plt.show()

#Lasso
C=[0.001,0.01,0.1,1,5,10,50,100,500,1000,1500]
mean_error=[]
std_error=[]
for Ci in C:
  model = Lasso(alpha=1/(2*Ci))
  temp=[]
  from sklearn.model_selection import KFold
  kf = KFold(n_splits=5)
  kfld=0
  for train,test in kf.split(feature_matrix):
    model.fit(feature_matrix[train],target_matrix[train])
    ypred = model.predict(feature_matrix[test])
    from sklearn.metrics import mean_squared_error
    temp.append(mean_squared_error(target_matrix[test],ypred))
    print(f"for c= {Ci} score={model.score(feature_matrix[test],target_matrix[test])} fold{kfld}")
    kfld+=1
  mean_error.append(np.array(temp).mean())
  std_error.append(np.array(temp).std())

print(f"Mean Square error {mean_error}")
print(f"Std  error {std_error}")
plt.errorbar(C,mean_error,yerr=std_error)
plt.xlabel('C'); plt.ylabel('Mean square error')
plt.title("Lasso Regression")
plt.show()



#RandomForest

estimators=[100, 200, 300, 1000]
mean_error=[]
std_error=[]
for Ei in estimators:
  model = RandomForestRegressor(n_estimators=Ei)
  temp=[]
  from sklearn.model_selection import KFold
  kf = KFold(n_splits=5)
  kfld=0
  for train,test in kf.split(feature_matrix):
    model.fit(feature_matrix[train],target_matrix[train])
    ypred = model.predict(feature_matrix[test])
    from sklearn.metrics import mean_squared_error
    temp.append(mean_squared_error(target_matrix[test],ypred))
    print(f"for c= {Ei} score={model.score(feature_matrix[test],target_matrix[test])} fold{kfld}")
    kfld+=1
  mean_error.append(np.array(temp).mean())
  std_error.append(np.array(temp).std())

print(f"Mean Square error {mean_error}")
print(f"Std  error {std_error}")
plt.errorbar(estimators,mean_error,yerr=std_error)
plt.xlabel('C'); plt.ylabel('Mean square error')
plt.title("Random Forest Regression")
plt.show()

#Dummy
# from sklearn.dummy import DummyRegressor
# dummy_regr = DummyRegressor(strategy="mean")
# dummy_regr.fit(X, y)


# #XGBoost
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(feature_matrix,target_matrix, test_size=0.2, random_state=123)

# kf = KFold(n_splits=5)
# kfld=0
# for train,test in kf.split(feature_matrix):
#   xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,max_depth = 5, alpha = 10, n_estimators = 10)
#   xg_reg.fit(feature_matrix[train],target_matrix[train])
#   ypred = xg_reg.predict(feature_matrix[test])
#   from sklearn.metrics import mean_squared_error
#   temp.append(mean_squared_error(target_matrix[test],ypred))
#   print(f"XG Boost score={model.score(feature_matrix[test],target_matrix[test])} fold{kfld}")
#   kfld+=1





# preds = xg_reg.predict(X_test)

# rmse = np.sqrt(mean_squared_error(y_test, preds))
# print("RMSE: %f" % (rmse))
# Out:
#  Correlation 0.6642506816947612
# Index(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')
#  Correlation 0.7425234799719985
# Index(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')
#  Correlation 0.7367731210379397
# Index(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')
#  Correlation 0.6365563853580499
# Index(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')
#  Correlation 0.6762174794141433
# Index(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
# ...

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
feature = pd.read_csv('sample_data/ChildPov_16_2006-2016.csv')
target = pd.read_csv('sample_data/Crime_2000-2017.csv')
feature_cols =feature.columns
target_cols =target.columns
for i in range(len(feature.columns)):
  # print(f" score {feature[].corr(target['2006.0'])}")
  print(f" Correlation {feature[feature_cols[i]].corr(target[feature_cols[i]])}")

feature_matrix = feature.iloc[:,:].to_numpy()
target_matrix = target.iloc[:,5:17].to_numpy()
X_train, X_test, y_train, y_test = train_test_split(feature_matrix, target_matrix,random_state=1)
C=[0.001,0.01,0.1,1,5,10,50,100,500,1000]
mean_error = []
std_error = []
for Ci in C:
  model = MLPRegressor(random_state=1,alpha=1/(2*Ci), max_iter=5000)
  
  temp=[]
  from sklearn.model_selection import KFold
  kf = KFold(n_splits=5)
  kfld=0
  for train,test in kf.split(feature_matrix):
    model.fit(feature_matrix[train],target_matrix[train])
    ypred = model.predict(feature_matrix[test])
    from sklearn.metrics import mean_squared_error
    temp.append(mean_squared_error(target_matrix[test],ypred))
    print(f"for c= {Ci} score={model.score(feature_matrix[test],target_matrix[test])} fold{kfld}")
    kfld+=1
  mean_error.append(np.array(temp).mean())
  std_error.append(np.array(temp).std())
plt.errorbar(C,mean_error,yerr=std_error)
plt.xscale("log")
plt.xlabel('C')
plt.ylabel('Mean square error')
plt.title("MLP Regression")

plt.show()
# Out:
#  Correlation 0.8210544305088301
#  Correlation 0.7821025346502808
#  Correlation 0.7963192934057421
#  Correlation 0.7599640541957184
#  Correlation 0.7767628804631685
#  Correlation 0.7380098993608748
#  Correlation 0.7029209029699911
#  Correlation 0.733896546614824
#  Correlation 0.771745118101451
#  Correlation 0.7943285948732396
#  Correlation 0.8082021300341117
# for c= 0.001 score=-0.035565035354605846 fold0
# for c= 0.001 score=-0.7021278779097914 fold1
# for c= 0.001 score=-0.05609265168575844 fold2
# for c= 0.001 score=-0.05332621913092258 fold3
# for c= 0.001 score=-0.05639795912790182 fold4
# for c= 0.01 score=-0.026746924978867836 fold0
# for c= 0.01 score=-0.7054156688012708 fold1
# for c= 0.01 score=-0.05419536373231441 fold2
# for c= 0.01 score=-0.03231107007791351 fold3
# for c= 0.01 score=-0.036798541645217765 fold4
# for c= 0.1 score=0.0720471449174306 fold0
# for c= 0.1 score=-0.24183981278589553 fold1
# for c= 0.1 score=0.06615762396095722 fold2
# ...

# %% [markdown]
# MLP regressors for new dataset

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import numpy
from keras.optimizers import adam
import keras
from matplotlib import pyplot
from keras.callbacks import EarlyStopping
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from matplotlib import pyplot

pov_16 = pd.read_csv("ChildPov_16_2006-2016.csv")
target = pd.read_csv("Crime_2000-2017.csv")
pov_18 = pd.read_csv("ChildPov_18_2006-2016.csv")
earning = pd.read_csv("Earnings_2000-2017.csv")
female65 = pd.read_csv("Female65LifeExpect_2000-2017.csv")
female = pd.read_csv("FemaleLifeExpect_2000-2017.csv")
male65 = pd.read_csv("Male65LifeExpect_2000-2017.csv")
male = pd.read_csv("MaleLifeExpect_2000-2017.csv")
neet = pd.read_csv("NEETs_2009-2015.csv")
rent = pd.read_csv("Rents_2011-2017.csv")
traffic = pd.read_csv("Traffic_2010-2017.csv")
workless = pd.read_csv("Workless_2004-2017.csv")

earning = earning.iloc[:, 6:-1]
female = female.iloc[:-1, 6:-1]
female65 = female65.iloc[:, 5:-1]
male = male.iloc[:-1, 6:-1]
male65 = male65.iloc[:-1, 5:-1]
traffic = traffic.iloc[:, 6:-1]
workless = workless.iloc[:, 2:-1]
target = target.iloc[:, 6:-1]

earning_matrix = earninig.iloc[:, :].to_numpy()
earning_matrix = earning.iloc[:, :].to_numpy()
female_matrix = female.iloc[:, :].to_numpy()
female65_matrix = female65.iloc[:, :].to_numpy()
male_matrix = male.iloc[:, :].to_numpy()
male65_matrix = male65.iloc[:, :].to_numpy()
traffic_matrix = traffic.iloc[:, :].to_numpy()
workless_matrix = workless.iloc[:, :].to_numpy()
target_matrix = target.iloc[:, :].to_numpy()

x1 = earning_matrix.reshape(-1, 1)
x2 = female65_matrix.reshape(-1, 1)
x3 = female_matrix.reshape(-1, 1)
x4 = male_matrix.reshape(-1, 1)
x5 = male65_matrix.reshape(-1, 1)
x6 = traffic_matrix.reshape(-1, 1)
x7 = workless_matrix.reshape(-1, 1)
y = target_matrix.reshape(-1, 1)

XStack = np.column_stack((x1, x2, x3, x4, x5, x6, x7))

X_train, X_test, y_train, y_test = train_test_split(XStack, y, random_state=1)

model = Sequential()
model.add(Dense(128, activation="relu", input_dim=7))
model.add(Dense(32, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1, activation="linear"))
model.compile(loss='mean_squared_error', optimizer=Adam(lr=1e-3, decay=1e-3 / 200))
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10000000, batch_size=100, verbose=2,
                    callbacks=[es])

model.predict(X_test)
ypred = model.predict(X_test)

pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
plt.title('Training Set')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.plot(y_test,ypred,'ro')
scores = r2_score(y_test,ypred)
print(scores)
plt.show()
